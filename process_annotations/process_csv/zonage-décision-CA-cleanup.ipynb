# %% [markdown]
# # POC zonage décision CA - cleanup
# Based on “Sortie CSV - récap des demandes.docx”.
#
# A bit of clean up, and adds a few new columns extracted from the data.
#
# We chose to keep the original data unchanged (especially `types`), and to add new values for a sample task (classification).

# %% [markdown]
# ## Libs versions

# %%
import os
import pathlib
import csv as csv
import pandas as pd
import numpy as np
import itertools

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
np.__version__
# Out:
# '1.12.1'

# %% [markdown]
# ## Set display options (for the Jupyter notebook)

# %%
pd.options.display.max_colwidth = 100
pd.options.display.max_rows = 100

# %%
def contrasting_text_color(hex_color:str):
    """returns a color visible on `hex_color`.
    Typically the result is a text color visible with high contrast on
    a  `hex_color` background.
    Parameter format: `#rrvvbb`"""
    (r, g, b) = (hex_color[1:3], hex_color[3:5], hex_color[5:])
    return '#FFFFFF' if 1 - (int(r, 16) * 0.299 + int(g, 16) * 0.587 + int(b, 16) * 0.114) / 255 < 0.5 else '#00000'

def highlight_color(x:str):
    """≠ color background for each file"""
    
    max_val = int('0xFFFFFF', base=16)
    
    # 2 calls to hash() to get more different values when the file numbers are close
    dec_bg_color = int(int(str(np.abs(hash(str(hash(x)))))[-10:-4]) / 999999  * max_val)
    bg_color = '#%06X' % dec_bg_color
    fg_color = '#%06X' % (max_val - dec_bg_color)
    
    return 'background-color: {}; color: {};'.format(bg_color, contrasting_text_color(fg_color))

# %% [markdown]
# ## Load the CSV (generated by `annotations2csv.py`)

# %%
dir_base = '/home/ojeulin/developpement/data/IA-et-droit-zonage-décisions-lots/brat_6-12'
file_csv_annotations = pathlib.Path(dir_base) / 'annotations.csv'

csv_separator_in = ','
csv_separator_out = ','
csv_encoding = 'utf-8'
n_a_value = 'n_a' # value for 'not applicable'

# %%
print(f'data file: {file_csv_annotations}')
# Out:
# data file: /home/ojeulin/developpement/data/IA-et-droit-zonage-décisions-lots/brat_6-12/annotations.csv

# %%
df = pd.read_table(file_csv_annotations,
                   sep=csv_separator_in,
                   encoding=csv_encoding)

# %%
df.head(3)
# Out:
#                                                                                               filename  \
# 0  /home/ojeulin/developpement/data/france/cours-appel-zonnées/brat_6-12/lot_0037/JURITEXT000033216...
# 1  /home/ojeulin/developpement/data/france/cours-appel-zonnées/brat_6-12/lot_0037/JURITEXT000033216...
# 2  /home/ojeulin/developpement/data/france/cours-appel-zonnées/brat_6-12/lot_0037/JURITEXT000033216...
#
#    line_num types annotation_difficulty                        text
# 0         1   n_a             Difficile  COUR D'APPEL DE VERSAILLES
# 1         2   n_a             Difficile              Code nac : 53B
# 2         3   n_a             Difficile                 16e chambre

# %% [markdown]
# ### Consistency check (works only for \*nix-like OS)

# %%
def check_csv_nb_lines(file_csv, df):
    wc = !wc -l "$file_csv"
    line_count_csv = int(wc[0].split(' ')[0]) - 1 # skip 1st line, the header
    line_count_df = df.shape[0]
    assert line_count_csv == line_count_df, f'Error: number of lines in the CSV file (#{line_count_csv}) ≠ number of lines in the DataFrame (#{line_count_df})'

# %%
check_csv_nb_lines(file_csv_annotations, df)

# %% [markdown]
# ## Cleaning the raw data

# %% [markdown]
# ### Extract the filename's informations we need
# Extract the last directory's name (= *batch* name) and the file name from the `filename` column, and drop it.

# %%
df2 = df.filename.str.rsplit('/', n=2, expand=True)
df['batch'] = df2[1]
df['file'] = df2[2]
del(df2)

# %%
df_clean =  df[list(filter(lambda s: s != 'filename', df.columns))].copy()
df_clean.shape
# Out:
# (52935, 6)

# %%
df_clean.head(3)
# Out:
#    line_num types annotation_difficulty                        text     batch  \
# 0         1   n_a             Difficile  COUR D'APPEL DE VERSAILLES  lot_0037
# 1         2   n_a             Difficile              Code nac : 53B  lot_0037
# 2         3   n_a             Difficile                 16e chambre  lot_0037
#
#                        file
# 0  JURITEXT000033216500.txt
# 1  JURITEXT000033216500.txt
# 2  JURITEXT000033216500.txt

# %% [markdown]
# ## Generate new data from existing columns

# %% [markdown]
# ### Vectorize `types` to columns `0/1`
# ⇒ it's easier to rename and delete types

# %%
df_types = df_clean.types.str.get_dummies(sep=' ')

# %% [markdown]
# ### Correct mispelled word in `types`
# Dipositif → Di**s**positif

# %%
df_types.rename(columns={'Dipositif': 'Dispositif'}, inplace=True);

# %%
types_values = df_types.columns # keep for later, if we need to change/delete
types_values
# Out:
# Index(['Dispositif', 'Dispositif-1', 'Dispositif-2', 'Dispositif-3',
#        'Dispositif-demandes_accessoires', 'Entete_appelant', 'Entete_avocat',
#        'Entete_composition_de_la_cour', 'Entete_intime', 'Expose_litige',
#        'Faits_et_procedure', 'Faits_et_procedure_faits',
#        'Faits_et_procedure_procedure', 'Motif-1', 'Motif-1_faits',
#        'Motif-1_pretentions_appelant', 'Motif-1_pretentions_intime',
#        'Motif-1_texte', 'Motif-2', 'Motif-2_faits',
#        'Motif-2_pretentions_appelant', 'Motif-2_pretentions_intime',
#        'Motif-2_texte', 'Motif-3', 'Motif-3_faits',
#        'Motif-3_pretentions_appelant', 'Motif-3_pretentions_intime',
#        'Motif-3_texte', 'Motif-demandes_accessoires', 'Motif_de_la_decision',
#        'Moyens_et_pretentions', 'Moyens_et_pretentions_appelant',
#        'Moyens_et_pretentions_intime', 'References_decision_attaquee', 'n_a'],
#       dtype='object')

# %% [markdown]
# Add the vectorized columns.

# %%
df_clean_vec = pd.concat([df_clean, df_types], axis=1)

# %%
df_clean_vec.columns
# Out:
# Index(['line_num', 'types', 'annotation_difficulty', 'text', 'batch', 'file',
#        'Dispositif', 'Dispositif-1', 'Dispositif-2', 'Dispositif-3',
#        'Dispositif-demandes_accessoires', 'Entete_appelant', 'Entete_avocat',
#        'Entete_composition_de_la_cour', 'Entete_intime', 'Expose_litige',
#        'Faits_et_procedure', 'Faits_et_procedure_faits',
#        'Faits_et_procedure_procedure', 'Motif-1', 'Motif-1_faits',
#        'Motif-1_pretentions_appelant', 'Motif-1_pretentions_intime',
#        'Motif-1_texte', 'Motif-2', 'Motif-2_faits',
#        'Motif-2_pretentions_appelant', 'Motif-2_pretentions_intime',
#        'Motif-2_texte', 'Motif-3', 'Motif-3_faits',
#        'Motif-3_pretentions_appelant', 'Motif-3_pretentions_intime',
#        'Motif-3_texte', 'Motif-demandes_accessoires', 'Motif_de_la_decision',
#        'Moyens_et_pretentions', 'Moyens_et_pretentions_appelant',
#        'Moyens_et_pretentions_intime', 'References_decision_attaquee', 'n_a'],
#       dtype='object')

# %% [markdown]
# ### Add the total number of lines per file

# %%
df_clean_total_lines = df_clean_vec.merge(
    pd.DataFrame((df_clean_vec.assign(total_line_number=df_clean.line_num)
                          .groupby(['file'])
                          .total_line_number.max())),
    left_on='file', right_index=True)

# %% [markdown]
# Check…

# %%
slice = df_clean_total_lines.total_line_number[0]
df_clean_total_lines.loc[slice-2:slice+1, ['file', 'line_num', 'total_line_number']]
# Out:
#                          file  line_num  total_line_number
# 175  JURITEXT000033216500.txt       176                177
# 176  JURITEXT000033216500.txt       177                177
# 177  JURITEXT000033214445.txt         1                 60
# 178  JURITEXT000033214445.txt         2                 60

# %% [markdown]
# ### Add types_macro
# **Types macro** : Entete, Expose_litige, Motif_de_la_decision, Dispositif.
# - début de la décision au 1er type macro → Entete
# - types pour les lignes comprises dans [Expose_litige, Motif_de_la_decision[ → Expose_litige
# - types pour les lignes comprises dans [Motif_de_la_decision, Dispositif[ → Motif_de_la_decision
# - types pour les lignes comprises dans [Dispositif, *fin du fichier*] → Dispositif
#
# ⇒ using forward fill N/A : ffill()

# %% [markdown]
# Check the data…

# %%
types_macro_cols = ['Expose_litige', 'Motif_de_la_decision', 'Dispositif']
types_macro = ['Entete'] + types_macro_cols

# %%
df_clean_total_lines[df_clean_total_lines[types_macro_cols].any(axis=1)][['line_num', 'batch', 'file'] + types_macro_cols].head().style.applymap(highlight_color, subset='file')
# Out:
# <style  type="text/css" >
#     #T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow0_col2 {
#             background-color:  #7D0813;
#              color:  #FFFFFF;
#         }    #T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow1_col2 {
#             background-color:  #7D0813;
#              color:  #FFFFFF;
#         }    #T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow2_col2 {
#             background-color:  #7D0813;
#              color:  #FFFFFF;
#         }    #T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow3_col2 {
#             background-color:  #34354B;
#              color:  #FFFFFF;
#         }    #T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow4_col2 {
#             background-color:  #34354B;
#              color:  #FFFFFF;
#         }</style>
# <table id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fd" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >line_num</th>
#         <th class="col_heading level0 col1" >batch</th>
#         <th class="col_heading level0 col2" >file</th>
#         <th class="col_heading level0 col3" >Expose_litige</th>
#         <th class="col_heading level0 col4" >Motif_de_la_decision</th>
#         <th class="col_heading level0 col5" >Dispositif</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdlevel0_row0" class="row_heading level0 row0" >29</th>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow0_col0" class="data row0 col0" >30</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow0_col1" class="data row0 col1" >lot_0037</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow0_col2" class="data row0 col2" >JURITEXT000033216500.txt</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow0_col3" class="data row0 col3" >1</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow0_col4" class="data row0 col4" >0</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow0_col5" class="data row0 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdlevel0_row1" class="row_heading level0 row1" >87</th>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow1_col0" class="data row1 col0" >88</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow1_col1" class="data row1 col1" >lot_0037</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow1_col2" class="data row1 col2" >JURITEXT000033216500.txt</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow1_col3" class="data row1 col3" >0</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow1_col4" class="data row1 col4" >1</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow1_col5" class="data row1 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdlevel0_row2" class="row_heading level0 row2" >167</th>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow2_col0" class="data row2 col0" >168</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow2_col1" class="data row2 col1" >lot_0037</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow2_col2" class="data row2 col2" >JURITEXT000033216500.txt</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow2_col3" class="data row2 col3" >0</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow2_col4" class="data row2 col4" >0</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow2_col5" class="data row2 col5" >1</td>
#     </tr>    <tr>
#         <th id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdlevel0_row3" class="row_heading level0 row3" >198</th>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow3_col0" class="data row3 col0" >22</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow3_col1" class="data row3 col1" >lot_0037</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow3_col2" class="data row3 col2" >JURITEXT000033214445.txt</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow3_col3" class="data row3 col3" >1</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow3_col4" class="data row3 col4" >0</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow3_col5" class="data row3 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdlevel0_row4" class="row_heading level0 row4" >221</th>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow4_col0" class="data row4 col0" >45</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow4_col1" class="data row4 col1" >lot_0037</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow4_col2" class="data row4 col2" >JURITEXT000033214445.txt</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow4_col3" class="data row4 col3" >0</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow4_col4" class="data row4 col4" >1</td>
#         <td id="T_35228c4a_fc3c_11e7_bf2c_507b9ddcd9fdrow4_col5" class="data row4 col5" >0</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# Create a column containing the index value of the list `types_macro` (sum the values of each lines):
#
# $$\text{DataFrame.types_macro} = \sum_{i=0}^{\text{len(types_macro_cols)}}
#                                        \text{DataFrame.}\mathit{\text{types_macro_cols}_i}  \cdot (i+1)$$
#
# ($\Leftrightarrow$ `df_clean_macro.types_macro = df_clean_macro.types_macro + df_clean_macro[colname] * i`, but using pandas's vectorized operations)

# %%
df_clean_macro = df_clean_total_lines.copy()

ones_serie = pd.Series(1, index=np.arange(df_clean_macro.shape[0]))
mult_df = pd.DataFrame({i: ones_serie * i for i in range(1, len(types_macro_cols) + 1)})
df_clean_macro['types_macro'] = pd.DataFrame.sum(df_clean_macro[types_macro_cols] * mult_df.values, axis=1)

# %% [markdown]
# Check…

# %%
df_clean_macro[df_clean_macro[types_macro_cols].any(axis=1)][['types_macro'] + types_macro_cols].head()
# Out:
#      types_macro  Expose_litige  Motif_de_la_decision  Dispositif
# 29             1              1                     0           0
# 87             2              0                     1           0
# 167            3              0                     0           1
# 198            1              1                     0           0
# 221            2              0                     1           0

# %%
# propagate the values:
# replace 0 with NaN, set the Entete index for the 1st lines, then ffill
df_clean_macro.loc[df_clean_macro.types_macro == 0, 'types_macro'] = np.nan
df_clean_macro.loc[df_clean_macro.line_num == 1, 'types_macro'] = 0 # index of 'Entete' in the list 'types_macro'
df_clean_macro.types_macro.ffill(inplace=True)
df_clean_macro.types_macro.astype(int);

# %%
# convert values to labels
mapping_types_macro = {idx: label for (idx, label) in enumerate(types_macro)}
df_clean_macro.types_macro = df_clean_macro.types_macro.map(mapping_types_macro)

# %% [markdown]
# Check…

# %%
df_clean_macro.types_macro.sample(5)
# Out:
# 29591                  Entete
# 48560    Motif_de_la_decision
# 34351              Dispositif
# 17573    Motif_de_la_decision
# 14059                  Entete
# Name: types_macro, dtype: object

# %% [markdown]
# ### Define generic functions to add a new column based on the value of other columns in a dataframe

# %%
def filter_row(df, by_cols, strict):
    """returns an index of row that are `True` if any value in `by_cols`
    is True.
    If `strict == True`, then other columns must all be False, else only `by_cols` is used
    """
    # we must remove the 'n_a' column because it's useless when comparing types with 'strict' == True
    other_cols = list(itertools.filterfalse(lambda col: col in by_cols + ['n_a'],
                                            types_values))
    result = df[by_cols].any(axis=1)
    if strict:
        result = result & ~(df[other_cols].any(axis=1))
        
    return result[result == True].index


def get_values(df, col, by_cols, value, strict):
    """returns a new `Serie` where `value` is set if any value in `by_cols` is `True`;
    the strictness of the comparison is given by `strict` (see function `filter_row`)
    """
    result = df[col].copy() # we will add new values, and keep existing ones
    result.loc[filter_row(df, by_cols, strict)] = value
    
    return result


def set_col_value(df, col, by_cols, value, strict=False):
    """set a `value` for `df.col` (returns a modified copy of df) based on `by_cols`, using
    a `strict` match (see `get_values()`)"""
    result = df.copy()
    result[col] = get_values(df=df, col=col, by_cols=by_cols, value=value, strict=strict)

    return result

# %% [markdown]
# ### Add column `sub_type`

# %%
def set_sub_type(df):
    col = 'sub_type'
    return (df
            .pipe(set_col_value, col,
                  ['References_decision_attaquee'],
                  'References_decision_attaquee')
            .pipe(set_col_value, col,
                  ['Entete_appelant', 'Entete_intime'],
                  'Entete_parties',
                  True)
            .pipe(set_col_value, col,
                  ['Entete_avocat'],
                  'Entete_avocat')
            .pipe(set_col_value, col,
                  ['Entete_composition_de_la_cour'],
                  'Entete_composition_de_la_cour')
            .pipe(set_col_value, col,
                  ['Faits_et_procedure', 'Faits_et_procedure_faits', 'Faits_et_procedure_procedure'],
                  'Faits_et_procedure',
                  True)
            .pipe(set_col_value, col,
                  ['Moyens_et_pretentions', 'Moyens_et_pretentions_appelant', 'Moyens_et_pretentions_intime'],
                  'Moyens_et_pretentions',
                  True)
            .pipe(set_col_value, col,
                  ['Motif-1_texte', 'Motif-2_texte', 'Motif-3_texte'],
                  'Motif_texte')
            .pipe(set_col_value, col,
                  ['Motif-1_faits', 'Motif-2_faits', 'Motif-3_faits'],
                  'Motif_faits',
                  True)
            .pipe(set_col_value, col,
                  ['Motif-1_pretentions_appelant', 'Motif-1_pretentions_intime', 'Motif-3_pretentions_appelant', 'Motif-3_pretentions_intime'],
                  'Motif_parties',
                  True)
            .pipe(set_col_value, col,
                  ['Motif-1', 'Motif-2', 'Motif-3'],
                  'Motif_juge',
                  True)
            .pipe(set_col_value, col,
                  ['Motif-demandes_accessoires'],
                  'Motif_demandes_accessoires')
            .pipe(set_col_value, col,
                  ['Dispositif-1', 'Dispositif-2', 'Dispositif-3'],
                  'Dispositif_contenu',
                  True)
            .pipe(set_col_value, col,
                  ['Dispositif-demandes_accessoires'],
                  'Dispositif_demandes_accessoires')
            .pipe(set_col_value, col,
                  ['n_a'],
                  n_a_value,
                  False)
            )

# %%
df_clean_st = df_clean_macro.copy()
# initialize the column's values
df_clean_st['sub_type'] = n_a_value

df_clean_st = set_sub_type(df_clean_st)

# %%
df_clean_st.sample(5)
# Out:
#        line_num                          types annotation_difficulty  \
# 51711        14  Entete_composition_de_la_cour                Facile
# 14309        35                            n_a                Facile
# 42280        73                        Motif-1            Impossible
# 7780         30                            n_a            Impossible
# 48801        58                        Motif-3                Facile
#
#                                                                                                       text  \
# 51711  En application des dispositions de l'article 945-1 du code de procédure civile, l'affaire a été ...
# 14309                                          **** L'incident a été fixé pour plaider le 25 octobre 2016.
# 42280  Le CGEA objecte que Monsieur X... ne démontre pas avoir fourni de prestation de travail, ni s'êt...
# 7780   " Mme X... n'ayant perçu que la somme de 26 689, 74 euros, il lui reste dû un montant de 10 680,...
# 48801  Attendu cependant que les termes du procès verbal font clairement état d'un engagement non seule...
#
#           batch                      file  Dispositif  Dispositif-1  \
# 51711  lot_0005  JURITEXT000033129005.txt           0             0
# 14309  lot_0025  JURITEXT000033435397.txt           0             0
# 42280  lot_0056  JURITEXT000033535981.txt           0             0
# 7780   lot_0057  JURITEXT000033533572.txt           0             0
# 48801  lot_0047  JURITEXT000033492486.txt           0             0
#
#        Dispositif-2  Dispositif-3              ...                \
# 51711             0             0              ...
# 14309             0             0              ...
# 42280             0             0              ...
# 7780              0             0              ...
# 48801             0             0              ...
#
#        Motif-demandes_accessoires  Motif_de_la_decision  \
# 51711                           0                     0
# 14309                           0                     0
# 42280                           0                     0
# 7780                            0                     0
# 48801                           0                     0
#
#        Moyens_et_pretentions  Moyens_et_pretentions_appelant  \
# 51711                      0                               0
# 14309                      0                               0
# 42280                      0                               0
# 7780                       0                               0
# 48801                      0                               0
#
#        Moyens_et_pretentions_intime  References_decision_attaquee  n_a  \
# 51711                             0                             0    0
# 14309                             0                             0    1
# 42280                             0                             0    0
# 7780                              0                             0    1
# 48801                             0                             0    0
#
#        total_line_number           types_macro                       sub_type
# 51711                104                Entete  Entete_composition_de_la_cour
# 14309                 57         Expose_litige                            n_a
# 42280                130  Motif_de_la_decision                     Motif_juge
# 7780                  33                Entete                            n_a
# 48801                 88  Motif_de_la_decision                     Motif_juge
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Add column `Parties`

# %%
def set_parties(df):
    col = 'Parties'
    return (df
            .pipe(set_col_value, col,
                  ['Entete_appelant', 'Moyens_et_pretentions_appelant', 'Motif-1_pretentions_appelant', 'Motif-2_pretentions_appelant', 'Motif-3_pretentions_appelant'],
                  'Appelant')
            .pipe(set_col_value, col,
                  ['Entete_intime', 'Moyens_et_pretentions_intime', 'Motif-1_pretentions_intime', 'Motif-2_pretentions_intime', 'Motif-3_pretentions_intime'],
                  'Intime',
                  True)
            )

# %%
df_clean_parties = df_clean_st.copy()
# initialize the column's values
df_clean_parties['Parties'] = n_a_value
df_clean_parties = set_parties(df_clean_parties)

# %%
df_clean_parties.sample(15)
# Out:
#        line_num                           types annotation_difficulty  \
# 30052        32                             n_a                 Moyen
# 3332         38    Faits_et_procedure_procedure                 Moyen
# 1944         95    Faits_et_procedure_procedure             Difficile
# 48393         5                             n_a                 Moyen
# 32724        48                         Motif-1            Impossible
# 51549        51                             n_a                 Moyen
# 12394        47  Moyens_et_pretentions_appelant                Facile
# 21054        26        Faits_et_procedure_faits                Facile
# 49989        36        Faits_et_procedure_faits                 Moyen
# 17186        30   Entete_composition_de_la_cour                Facile
# 8986         49  Moyens_et_pretentions_appelant                Facile
# 30703        43              Faits_et_procedure                 Moyen
# 29334        18   Entete_composition_de_la_cour            Impossible
# 24446       146                             n_a            Impossible
# 35631         2                             n_a            Impossible
#
#                                                                                                       text  \
# 30052                                                                                       CONTRADICTOIRE
# 3332                                                                                    - en conséquence :
# 1944                                                     Celui-ci a déposé son rapport le 24 juillet 2015.
# 48393                                                       RÉPUBLIQUE FRANÇAISE-AU NOM DU PEUPLE FRANÇAIS
# 32724                                                                        -Sur l'annulation du jugement
# 51549          Mme Ghislaine A... épouse B..., assignée à l'étude de l'huissier, n'a pas constitué avocat.
# 12394     Par déclaration reçue le 19 février 2015, Mme X... épouse Y... a interjeté appel de ce jugement.
# 21054  M. X...y a répondu le 4 novembre 2013 en faisant des observations sur le redressement forfaitair...
# 49989  Il résulte des pièces du dossier que les époux X...ont divorcé en 1997, la résidence de l'enfant...
# 17186                                                                           GREFFIER LORS DES DEBATS :
# 8986                                                                jusqu'à la prochaine rentrée scolaire,
# 30703  Exposant avoir mis en œuvre sa garantie pour un montant de 171. 135, 63 €, l'APST a déclaré cett...
# 29334  Ce magistrat a rendu compte des plaidoiries dans le délibéré de la cour, composée de : Madame Ma...
# 24446  Il ressort tant de l'audition de Céline A...que de celle de Chloé C..., stagiaire, qui les a acc...
# 35631                                                                                COUR D'APPEL DE PARIS
#
#           batch                      file  Dispositif  Dispositif-1  \
# 30052  lot_0027  JURITEXT000033267186.txt           0             0
# 3332   lot_0003  JURITEXT000033886060.txt           0             0
# 1944   lot_0014  JURITEXT000033184342.txt           0             0
# 48393  lot_0047  JURITEXT000033492406.txt           0             0
# 32724  lot_0048  JURITEXT000033490035.txt           0             0
# 51549  lot_0005  JURITEXT000033354589.txt           0             0
# 12394  lot_0019  JURITEXT000033183991.txt           0             0
# 21054  lot_0002  JURITEXT000033129308.txt           0             0
# 49989  lot_0035  JURITEXT000033215895.txt           0             0
# 17186  lot_0044  JURITEXT000033490156.txt           0             0
# 8986   lot_0004  JURITEXT000033886060.txt           0             0
# 30703  lot_0027  JURITEXT000033267131.txt           0             0
# 29334  lot_0050  JURITEXT000033491008.txt           0             0
# 24446  lot_0028  JURITEXT000033266138.txt           0             0
# 35631  lot_0053  JURITEXT000033130535.txt           0             0
#
#        Dispositif-2  Dispositif-3    ...     Motif_de_la_decision  \
# 30052             0             0    ...                        0
# 3332              0             0    ...                        0
# 1944              0             0    ...                        0
# 48393             0             0    ...                        0
# 32724             0             0    ...                        0
# 51549             0             0    ...                        0
# 12394             0             0    ...                        0
# 21054             0             0    ...                        0
# 49989             0             0    ...                        0
# 17186             0             0    ...                        0
# 8986              0             0    ...                        0
# 30703             0             0    ...                        0
# 29334             0             0    ...                        0
# 24446             0             0    ...                        0
# 35631             0             0    ...                        0
#
#        Moyens_et_pretentions  Moyens_et_pretentions_appelant  \
# 30052                      0                               0
# 3332                       0                               0
# 1944                       0                               0
# 48393                      0                               0
# 32724                      0                               0
# 51549                      0                               0
# 12394                      0                               1
# 21054                      0                               0
# 49989                      0                               0
# 17186                      0                               0
# 8986                       0                               1
# 30703                      0                               0
# 29334                      0                               0
# 24446                      0                               0
# 35631                      0                               0
#
#        Moyens_et_pretentions_intime  References_decision_attaquee  n_a  \
# 30052                             0                             0    1
# 3332                              0                             0    0
# 1944                              0                             0    0
# 48393                             0                             0    1
# 32724                             0                             0    0
# 51549                             0                             0    1
# 12394                             0                             0    0
# 21054                             0                             0    0
# 49989                             0                             0    0
# 17186                             0                             0    0
# 8986                              0                             0    0
# 30703                             0                             0    0
# 29334                             0                             0    0
# 24446                             0                             0    1
# 35631                             0                             0    1
#
#        total_line_number           types_macro                       sub_type  \
# 30052                 73                Entete                            n_a
# 3332                 114         Expose_litige             Faits_et_procedure
# 1944                 182         Expose_litige             Faits_et_procedure
# 48393                 96                Entete                            n_a
# 32724                 86  Motif_de_la_decision                     Motif_juge
# 51549                 76         Expose_litige                            n_a
# 12394                 80         Expose_litige          Moyens_et_pretentions
# 21054                 82         Expose_litige             Faits_et_procedure
# 49989                102         Expose_litige             Faits_et_procedure
# 17186                112                Entete  Entete_composition_de_la_cour
# 8986                 114         Expose_litige          Moyens_et_pretentions
# 30703                 94         Expose_litige             Faits_et_procedure
# 29334                 70                Entete  Entete_composition_de_la_cour
# 24446                207  Motif_de_la_decision                            n_a
# 35631                 64                Entete                            n_a
#
#         Parties
# 30052       n_a
# 3332        n_a
# 1944        n_a
# 48393       n_a
# 32724       n_a
# 51549       n_a
# 12394  Appelant
# 21054       n_a
# 49989       n_a
# 17186       n_a
# 8986   Appelant
# 30703       n_a
# 29334       n_a
# 24446       n_a
# 35631       n_a
#
# [15 rows x 45 columns]

# %% [markdown]
# ### Add column `Argument`

# %%
# values are overwriten by the next pipe(), so we order them from least to max priority

def set_argument(df):
    col = 'Argument'
    return (df
            .pipe(set_col_value, col,
                  ['Motif-3', 'Motif-3_pretentions_appelant', 'Motif-3_pretentions_intime', 'Motif-3_texte', 'Motif-3_faits', 'Dispositif-3'],
                  3)
            .pipe(set_col_value, col,
                  ['Motif-2', 'Motif-2_pretentions_appelant', 'Motif-2_pretentions_intime', 'Motif-2_texte', 'Motif-2_faits', 'Dispositif-2'],
                  2)
            .pipe(set_col_value, col,
                  ['Motif-1', 'Motif-1_pretentions_appelant', 'Motif-1_pretentions_intime', 'Motif-1_texte', 'Motif-1_faits', 'Dispositif-1'],
                  1)
            )

# %%
df_clean_arg = df_clean_parties.copy()
df_clean_arg['Argument'] = np.nan # the number of the argument used in the case
df_clean_arg = set_argument(df_clean_arg)

# %%
df_clean_arg.sample(15)
# Out:
#        line_num                           types annotation_difficulty  \
# 16252        23                             n_a                   n_a
# 28754       118            Motif_de_la_decision            Impossible
# 46349        48    Moyens_et_pretentions_intime                 Moyen
# 6498         57                             n_a                 Moyen
# 39249        96    Moyens_et_pretentions_intime             Difficile
# 17274         6                             n_a            Impossible
# 52001         7                             n_a                Facile
# 49363        52    Moyens_et_pretentions_intime                 Moyen
# 107         108      Motif-2_pretentions_intime             Difficile
# 42977        13                             n_a            Impossible
# 30575       111  Moyens_et_pretentions_appelant            Impossible
# 23399        42                             n_a                Facile
# 9849          6                             n_a                Facile
# 12032        15                             n_a                 Moyen
# 5637         42                             n_a            Impossible
#
#                                                                                                       text  \
# 16252  L'EURL SEBASTIEN BOIS, qui a relevé appel le 24 mai 2016, a saisi le premier président d'une dem...
# 28754  Des constatations de l'expert qui a réalisé les comptes entre les parties, non critiquées à ce t...
# 46349  - débouter les consorts X...- Y... de leur appel dirigé contre la SARL Euro Immo,- confirmer le ...
# 6498   Disons que la présente ordonnance sera notifiée à Madame Y... Sarodal, son conseil Maître LETOUR...
# 39249  ordonné la réduction de loyer à hauteur de 300, 00 euros par mois à compter du 1er mars 2011 dan...
# 17274                                                                                COUR D'APPEL DE DIJON
# 52001                                                                                     COPIE AU DOSSIER
# 49363                                Par dernières conclusions du 5 octobre 2016, M. Z...prie la Cour de :
# 107    En effet, elle fait valoir que les contrats litigieux reposent sur une formule d'indexation basé...
# 42977  URSSAF de Franche-Comté aux droits de l'URSSAF de Haute-Saône11 boulevard des AlliésBP 158970022...
# 30575  La société Rosematel a expressément cantonné l'objet de son appel à la revendication du bénéfice...
# 23399                                                                               ARRÊT : CONTRADICTOIRE
# 9849                                                Numéro d'inscription au répertoire général : 15/ 09118
# 12032                                                                                                 ET :
# 5637                         - ordonné la publication et l'exécution de la décision conformément à la loi,
#
#           batch                      file  Dispositif  Dispositif-1  \
# 16252  lot_0052  JURITEXT000033130224.txt           0             0
# 28754  lot_0036  JURITEXT000033214806.txt           0             0
# 46349  lot_0007  JURITEXT000033354991.txt           0             0
# 6498   lot_0031  JURITEXT000033575740.txt           0             0
# 39249  lot_0010  JURITEXT000033353836.txt           0             0
# 17274  lot_0044  JURITEXT000033491724.txt           0             0
# 52001  lot_0005  JURITEXT000033785359.txt           0             0
# 49363  lot_0040  JURITEXT000033493478.txt           0             0
# 107    lot_0037  JURITEXT000033216500.txt           0             0
# 42977  lot_0049  JURITEXT000033492902.txt           0             0
# 30575  lot_0027  JURITEXT000033265998.txt           0             0
# 23399  lot_0022  JURITEXT000033436656.txt           0             0
# 9849   lot_0032  JURITEXT000033576403.txt           0             0
# 12032  lot_0019  JURITEXT000033488844.txt           0             0
# 5637   lot_0034  JURITEXT000033214782.txt           0             0
#
#        Dispositif-2  Dispositif-3    ...     Moyens_et_pretentions  \
# 16252             0             0    ...                         0
# 28754             0             0    ...                         0
# 46349             0             0    ...                         0
# 6498              0             0    ...                         0
# 39249             0             0    ...                         0
# 17274             0             0    ...                         0
# 52001             0             0    ...                         0
# 49363             0             0    ...                         0
# 107               0             0    ...                         0
# 42977             0             0    ...                         0
# 30575             0             0    ...                         0
# 23399             0             0    ...                         0
# 9849              0             0    ...                         0
# 12032             0             0    ...                         0
# 5637              0             0    ...                         0
#
#        Moyens_et_pretentions_appelant  Moyens_et_pretentions_intime  \
# 16252                               0                             0
# 28754                               0                             0
# 46349                               0                             1
# 6498                                0                             0
# 39249                               0                             1
# 17274                               0                             0
# 52001                               0                             0
# 49363                               0                             1
# 107                                 0                             0
# 42977                               0                             0
# 30575                               1                             0
# 23399                               0                             0
# 9849                                0                             0
# 12032                               0                             0
# 5637                                0                             0
#
#        References_decision_attaquee  n_a  total_line_number  \
# 16252                             0    1                 38
# 28754                             0    0                148
# 46349                             0    0                 71
# 6498                              0    1                 60
# 39249                             0    0                208
# 17274                             0    1                 69
# 52001                             0    1                 30
# 49363                             0    0                 83
# 107                               0    0                177
# 42977                             0    1                 65
# 30575                             0    0                120
# 23399                             0    1                 67
# 9849                              0    1                 52
# 12032                             0    1                 61
# 5637                              0    1                 74
#
#                 types_macro               sub_type   Parties  Argument
# 16252         Expose_litige                    n_a       n_a       NaN
# 28754  Motif_de_la_decision                    n_a       n_a       NaN
# 46349         Expose_litige  Moyens_et_pretentions    Intime       NaN
# 6498             Dispositif                    n_a       n_a       NaN
# 39249         Expose_litige  Moyens_et_pretentions    Intime       NaN
# 17274                Entete                    n_a       n_a       NaN
# 52001                Entete                    n_a       n_a       NaN
# 49363         Expose_litige  Moyens_et_pretentions    Intime       NaN
# 107    Motif_de_la_decision                    n_a    Intime       2.0
# 42977                Entete                    n_a       n_a       NaN
# 30575  Motif_de_la_decision  Moyens_et_pretentions  Appelant       NaN
# 23399                Entete                    n_a       n_a       NaN
# 9849                 Entete                    n_a       n_a       NaN
# 12032                Entete                    n_a       n_a       NaN
# 5637          Expose_litige                    n_a       n_a       NaN
#
# [15 rows x 46 columns]

# %% [markdown]
# ## Save as CSV

# %%
file_result = pathlib.Path(dir_base) / 'annotations-clean.csv'

# %%
#cols_for_csv = list(filter(lambda s: s not in types_values, list(df_clean_parties.columns)))
cols_for_csv = ['batch', 'file', 'total_line_number', 'line_num', 'types', 'annotation_difficulty', 'types_macro', 'sub_type', 'Parties', 'Argument', 'text']
print(f'Columns of the CSV:\n{cols_for_csv}', end='\n\n')

df_clean_arg.to_csv(file_result,
                index=None,
                sep=csv_separator_out,
                columns=cols_for_csv,
                quoting=csv.QUOTE_NONNUMERIC,
                encoding=csv_encoding)
print(f'Result in {file_result}')
# Out:
# Columns of the CSV:
# ['batch', 'file', 'total_line_number', 'line_num', 'types', 'annotation_difficulty', 'types_macro', 'sub_type', 'Parties', 'Argument', 'text']
#
# Result in /home/ojeulin/developpement/data/IA-et-droit-zonage-décisions-lots/brat_6-12/annotations-clean.csv

# %% [markdown]
# # Print the sorted list of values for types, types_macro, sub_type, Parties, Argument:

# %%
print('——————— types ———————')
for t in sorted(list({t for tt in df_clean_arg.types.str.split(' ').tolist() for t in tt})):
    print(t)

for col in ['types_macro', 'sub_type', 'Parties', 'Argument']:
    print(f'\n——————— {col} ———————')
    for t in sorted(list(df_clean_arg[col].unique())):
        print(t)
# Out:
# ——————— types ———————
# Dipositif
# Dispositif-1
# Dispositif-2
# Dispositif-3
# Dispositif-demandes_accessoires
# Entete_appelant
# Entete_avocat
# Entete_composition_de_la_cour
# Entete_intime
# Expose_litige
# Faits_et_procedure
# Faits_et_procedure_faits
# Faits_et_procedure_procedure
# Motif-1
# Motif-1_faits
# Motif-1_pretentions_appelant
# Motif-1_pretentions_intime
# Motif-1_texte
# Motif-2
# Motif-2_faits
# Motif-2_pretentions_appelant
# Motif-2_pretentions_intime
# Motif-2_texte
# Motif-3
# Motif-3_faits
# Motif-3_pretentions_appelant
# Motif-3_pretentions_intime
# Motif-3_texte
# Motif-demandes_accessoires
# Motif_de_la_decision
# Moyens_et_pretentions
# Moyens_et_pretentions_appelant
# Moyens_et_pretentions_intime
# References_decision_attaquee
# n_a
#
# ——————— types_macro ———————
# Dispositif
# Entete
# Expose_litige
# Motif_de_la_decision
#
# ——————— sub_type ———————
# Dispositif_contenu
# Dispositif_demandes_accessoires
# Entete_avocat
# Entete_composition_de_la_cour
# Entete_parties
# Faits_et_procedure
# Motif_demandes_accessoires
# Motif_faits
# Motif_juge
# Motif_parties
# Motif_texte
# Moyens_et_pretentions
# References_decision_attaquee
# n_a
#
# ——————— Parties ———————
# Appelant
# Intime
# n_a
#
# ——————— Argument ———————
# nan
# 1.0
# 2.0
# 3.0
